# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/al_grid.csv")
df
# Out:
#            X     Y        Total  Not Hispanic or Latino  White alone  \
# 0       1035  1482   411.912900              405.766233    21.020359
# 1       1035  1481  1143.021901             1114.305927    53.729173
# 2       1036  1482   723.120458              705.572521    20.577286
# 3       1036  1483   495.929274              495.279686     3.317756
# 4        937  1084   580.401346              567.534888   308.349776
# ...      ...   ...          ...                     ...          ...
# 208186   998  1225     7.106532                7.106532     7.056486
# 208187   998  1224     7.106532                7.106532     7.056486
# 208188   998  1223     7.106532                7.106532     7.056486
# 208189   998  1222     7.106532                7.106532     7.056486
# 208190   870  1674     0.000000                0.000000     0.000000
#
#         Black or African American alone  \
# 0                            376.270580
# 1                           1046.875416
# ...

# %%
# filtered_df = df.loc[df["Total"] > 100]
filtered_df = df

# %%
sac_zone_df = pd.DataFrame(filtered_df[filtered_df["ilcr"] != 0])

sns.kdeplot(sac_zone_df["Black or African American alone %"])
sns.kdeplot(filtered_df["Black or African American alone %"])

plt.show()

# %%
sac_zone_df = pd.DataFrame(filtered_df[filtered_df["ilcr"] != 0])

sns.kdeplot(sac_zone_df["White alone %"])
sns.kdeplot(filtered_df["White alone %"])

plt.show()

# %%
sac_zone_df = pd.DataFrame(filtered_df[filtered_df["ilcr"] != 0])

sns.kdeplot(sac_zone_df["American Indian and Alaska Native alone %"])
sns.kdeplot(filtered_df["American Indian and Alaska Native alone %"])

plt.show()

# %%
sac_zone_df = pd.DataFrame(filtered_df[filtered_df["ilcr"] != 0])

sns.kdeplot(sac_zone_df["Two or More Races %"])
sns.kdeplot(filtered_df["Two or More Races %"])

plt.show()

# %%
sac_zone_df = pd.DataFrame(filtered_df[filtered_df["ilcr"] != 0])

sns.kdeplot(sac_zone_df["Hispanic or Latino %"])
sns.kdeplot(filtered_df["Hispanic or Latino %"])

plt.show()
